# %%
import torch 
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
from GMF_model import GMF
from MLP_model import NCF_mlp
from NeuMF_model import NeuMF

# %%
# configurations = {
#     "train_data" : Path(os.getcwd()) / "NCF_Pytorch" / "train_data.csv",
#     "test_data" : Path(os.getcwd()) / "NCF_Pytorch" / "test_data.csv",
#     "test_negative_data" : Path(os.getcwd()) / "NCF_Pytorch" / "test_negative_data.csv",
#     'dataset': 'ml-1m',   ## name of dataset
#     'regs': [0, 0],       ## Regularigaion L1, L2
#     'lr': 0.001,          ## Learning Rate
#     'batch_size': batch_size,    ## Batch Size
#     'epochs': epochs,          ## Training Epochs
#     'learner': learner,    ## Optimizer
#     'num_factors': num_factors,    ## we used it as latent Dimensions
#     'num_neg': num_neg,         ## per User no of negative items
#     'out': True,          ## Save best model or not
#     'out_path' : Path(os.getcwd()) / "GMF_Models",
#     'topK' : topK            ## Used in Evaluation.
# }

# %%
train_df = pd.read_csv("/home/dhruv/Documents/NCF/NCF_Recommendation/NCF_Pytorch/train_data.csv")
train_df
# Out:
#         UserID  ItemID  Rating  Timestamp
# 0            0      32       4  978824330
# 1            0      34       4  978824330
# 2            0       4       5  978824291
# 3            0      35       4  978824291
# 4            0      30       4  978824291
# ...        ...     ...     ...        ...
# 994164    6039    1092       5  956703977
# 994165    6039      41       4  956703977
# 994166    6039     128       5  956703954
# 994167    6039     323       4  956703954
# 994168    6039     669       4  956703932
#
# [994169 rows x 4 columns]

# %%
num_Users = max(train_df["UserID"]) + 1
num_Users

num_items = max(train_df["ItemID"]) + 1
num_items
# Out:
# 3706

# %%
num_Users
# Out:
# 6040

# %%
gf_model = GMF()

# %%
gf_model
# Out:
# GMF(
#   (user_embeddings): Embedding(6040, 10)
#   (item_embeddings): Embedding(3706, 10)
#   (output): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
gf_model
# Out:
# GMF(
#   (user_embeddings): Embedding(6040, 10)
#   (item_embeddings): Embedding(3706, 10)
#   (output): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
gf_model.load_state_dict(torch.load("/home/dhruv/Documents/NCF/NCF_Recommendation/GMF_Models/ml-1m_GMF_Batch_128_epoch_10_10.pth"))
gf_model.eval()
# Out:
# GMF(
#   (user_embeddings): Embedding(6040, 10)
#   (item_embeddings): Embedding(3706, 10)
#   (output): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
user = torch.LongTensor([0])
item = torch.LongTensor([0])

# %%
user, item
# Out:
# (tensor([0]), tensor([0]))

# %%
out = gf_model(user, item)

out
# Out:
# tensor(0.9629, grad_fn=<SqueezeBackward0>)

# %%
from torchviz import make_dot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from torchviz import make_dot
#
# ModuleNotFoundError: No module named 'torchviz'
