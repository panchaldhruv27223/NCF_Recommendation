# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/dhruv/Documents/NCF/NCF_Recommendation/NCF_Pytorch/train_data.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994169 entries, 0 to 994168
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   UserID     994169 non-null  int64
#  1   ItemID     994169 non-null  int64
#  2   Rating     994169 non-null  int64
#  3   Timestamp  994169 non-null  int64
# dtypes: int64(4)
# memory usage: 30.3 MB

# %%
df.ItemID.nunique()
# Out:
# 3704

# %%
df.groupby(df.ItemID).count().sort_values("UserID")["UserID"].reset_index()
# Out:
#       ItemID  UserID
# 0       3705       1
# 1       3704       1
# 2       3639       1
# 3       3649       1
# 4       3650       1
# ...      ...     ...
# 3699     113    2660
# 3700      64    2876
# 3701      44    2978
# 3702     124    2985
# 3703     104    3405
#
# [3704 rows x 2 columns]
